# %% [markdown]
# # The Zen of Python

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# # Setting up Quandl for your environment

# %%
import pandas
pandas.__version__
# Out:
# '0.23.3'

# %% [markdown]
# # Plotting your first chart

# %% [markdown]
# ## Retrieving dataset from Quandl

# %%
import quandl

# Replace with your own Quandl API key
QUANDL_API_KEY = 'BCzkk3NDWt7H9yjzx-DY'  
quandl.ApiConfig.api_key = QUANDL_API_KEY
df = quandl.get('EURONEXT/ABN')

# %%
pip install quandl
# Out:
# Collecting quandl
#   Using cached https://files.pythonhosted.org/packages/07/ab/8cd479fba8a9b197a43a0d55dd534b066fb8e5a0a04b5c0384cbc5d663aa/Quandl-3.5.0-py2.py3-none-any.whl
# Requirement already satisfied: more-itertools in /workspace/conda/arcw/lib/python3.6/site-packages (from quandl) (7.2.0)
# Requirement already satisfied: six in /workspace/conda/arcw/lib/python3.6/site-packages (from quandl) (1.12.0)
# Requirement already satisfied: pandas>=0.14 in /workspace/conda/arcw/lib/python3.6/site-packages (from quandl) (0.25.2)
# Requirement already satisfied: requests>=2.7.0 in /workspace/conda/arcw/lib/python3.6/site-packages (from quandl) (2.22.0)
# Requirement already satisfied: numpy>=1.8 in /workspace/conda/arcw/lib/python3.6/site-packages (from quandl) (1.17.3)
# Collecting inflection>=0.3.1
#   Using cached https://files.pythonhosted.org/packages/d5/35/a6eb45b4e2356fe688b21570864d4aa0d0a880ce387defe9c589112077f8/inflection-0.3.1.tar.gz
# Requirement already satisfied: python-dateutil in /workspace/conda/arcw/lib/python3.6/site-packages (from quandl) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in /workspace/conda/arcw/lib/python3.6/site-packages (from pandas>=0.14->quandl) (2019.3)
# Requirement already satisfied: certifi>=2017.4.17 in /workspace/conda/arcw/lib/python3.6/site-packages (from requests>=2.7.0->quandl) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /workspace/conda/arcw/lib/python3.6/site-packages (from requests>=2.7.0->quandl) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /workspace/conda/arcw/lib/python3.6/site-packages (from requests>=2.7.0->quandl) (1.25.6)
# Requirement already satisfied: idna<2.9,>=2.5 in /workspace/conda/arcw/lib/python3.6/site-packages (from requests>=2.7.0->quandl) (2.8)
# Building wheels for collected packages: inflection
#   Building wheel for inflection (setup.py) ... done
#   Created wheel for inflection: filename=inflection-0.3.1-cp36-none-any.whl size=6076 sha256=2b62fb1c43ee070b8dd1abee730d6006aeaa345305c5121c8208852b09ab4a7c
#   Stored in directory: /home/gitpod/.cache/pip/wheels/9f/5a/d3/6fc3bf6516d2a3eb7e18f9f28b472110b59325f3f258fe9211
# Successfully built inflection
# Installing collected packages: inflection, quandl
# Successfully installed inflection-0.3.1 quandl-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
df.head()
# Out:
#              Open   High     Low   Last      Volume      Turnover
# Date
# 2015-11-20  18.18  18.43  18.000  18.35  38392898.0  7.003281e+08
# 2015-11-23  18.45  18.70  18.215  18.61   3352514.0  6.186446e+07
# 2015-11-24  18.70  18.80  18.370  18.80   4871901.0  8.994087e+07
# 2015-11-25  18.85  19.50  18.770  19.45   4802607.0  9.153862e+07
# 2015-11-26  19.48  19.67  19.410  19.43   1648481.0  3.220713e+07

# %%
df.tail()
# Out:
#               Open    High     Low    Last     Volume    Turnover
# Date
# 2020-01-21  16.000  16.075  15.715  15.715  4263634.0  67409129.0
# 2020-01-22  15.745  15.795  15.540  15.700  3133910.0  49021383.0
# 2020-01-23  15.650  15.830  15.560  15.785  4015875.0  63204977.0
# 2020-01-24  15.960  16.030  15.790  15.790  2182544.0  34674988.0
# 2020-01-27  15.610  15.780  15.455  15.565  2441339.0  38017351.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.plot();

# %% [markdown]
# ## Plotting a price and volume chart

# %%
prices = df['Last']
volumes = df['Volume']

# %%
prices.head()
# Out:
# Date
# 2015-11-20    18.35
# 2015-11-23    18.61
# 2015-11-24    18.80
# 2015-11-25    19.45
# 2015-11-26    19.43
# Name: Last, dtype: float64

# %%
volumes.tail()
# Out:
# Date
# 2018-08-07    1785613.0
# 2018-08-08    4165320.0
# 2018-08-09    2422470.0
# 2018-08-10    3951850.0
# 2018-08-13    2341326.0
# Name: Volume, dtype: float64

# %%
# The top plot consisting of dailing closing prices
top = plt.subplot2grid((4, 4), (0, 0), rowspan=3, colspan=4)
top.plot(prices.index, prices, label='Last')
plt.title('ABN Last Price from 2015 - 2018')
plt.legend(loc=2)

# The bottom plot consisting of daily trading volume
bottom = plt.subplot2grid((4, 4), (3,0), rowspan=1, colspan=4)
bottom.bar(volumes.index, volumes)
plt.title('ABN Daily Trading Volume')

plt.gcf().set_size_inches(12, 8)
plt.subplots_adjust(hspace=0.75)

# %% [markdown]
# ## Plotting a candlestick chart

# %%
# %matplotlib inline
import quandl
from mpl_finance import candlestick_ohlc
import matplotlib.dates as mdates
import matplotlib.pyplot as plt

quandl.ApiConfig.api_key = QUANDL_API_KEY
df_subset = quandl.get('EURONEXT/ABN', 
                       start_date='2018-07-01', 
                       end_date='2018-07-31')

df_subset['Date'] = df_subset.index.map(mdates.date2num)
df_ohlc = df_subset[['Date','Open', 'High', 'Low', 'Last']]

figure, ax = plt.subplots(figsize = (8,4))
formatter = mdates.DateFormatter('%Y-%m-%d')
ax.xaxis.set_major_formatter(formatter)
candlestick_ohlc(ax, 
                 df_ohlc.values, 
                 width=0.8, 
                 colorup='green', 
                 colordown='red')
plt.show()

# %% [markdown]
# # Performing Financial Analytics

# %% [markdown]
# ## Plotting returns

# %%
# %matplotlib inline
import quandl

quandl.ApiConfig.api_key = QUANDL_API_KEY
df = quandl.get('EURONEXT/ABN.4')
daily_changes = df.pct_change(periods=1)
daily_changes.plot();

# %% [markdown]
# ## Plotting cummulative returns

# %%
df_cumsum = daily_changes.cumsum()
df_cumsum.plot();

# %% [markdown]
# ## Plotting Histograms

# %%
daily_changes.hist(bins=50, figsize=(8, 4));

# %%
daily_changes.describe()
# Out:
#              Last
# count  693.000000
# mean     0.000483
# std      0.016695
# min     -0.125527
# 25%     -0.008100
# 50%      0.000552
# 75%      0.008753
# max      0.059123

# %% [markdown]
# ## Plotting volatility

# %%
df_filled = df.asfreq('D', method='ffill')
df_returns = df_filled.pct_change()
df_std = df_returns.rolling(window=30, min_periods=30).std()
df_std.plot();

# %% [markdown]
# ## Quantile-Quantile Plot

# %%
# %matplotlib inline
import quandl
from scipy import stats
from scipy.stats import probplot

quandl.ApiConfig.api_key = QUANDL_API_KEY
df = quandl.get('EURONEXT/ABN.4')
daily_changes = df.pct_change(periods=1).dropna()

figure = plt.figure(figsize=(8,4))
ax = figure.add_subplot(111)
stats.probplot(daily_changes['Last'], dist='norm', plot=ax)
plt.show();

# %% [markdown]
# ## Downloading multiple time series data

# %%
# %matplotlib inline
import quandl

quandl.ApiConfig.api_key = QUANDL_API_KEY
df = quandl.get(['EURONEXT/ABN.4', 
                 'EURONEXT/SANTA.4', 
                 'EURONEXT/KA.4'], 
                collapse='monthly', 
                start_date='2016-01-01', 
                end_date='2019-12-31')

df.plot();
print(df)
# Out:
#             EURONEXT/ABN - Last  EURONEXT/SANTA - Last  EURONEXT/KA - Last
# Date
# 2016-01-31               19.240                 3.9400               9.850
# 2016-02-29               18.240                 3.6700              10.080
# 2016-03-31               18.005                 3.9500              10.115
# 2016-04-30               18.670                 4.5000               9.091
# 2016-05-31               18.305                 4.3600               9.000
# 2016-06-30               14.895                 3.3700               9.002
# 2016-07-31               16.620                 3.6600               9.580
# 2016-08-31               18.425                 4.0100               8.150
# 2016-09-30               18.420                 3.8000               8.010
# 2016-10-31               21.025                 4.4900               8.255
# 2016-11-30               20.400                 4.2900               8.350
# 2016-12-31               21.050                 4.7700               8.425
# 2017-01-31               21.750                 5.0200               8.525
# 2017-02-28               21.600                 5.1000               8.650
# 2017-03-31               22.750                 5.6000               9.748
# 2017-04-30               24.100                 6.0000              10.900
# 2017-05-31               22.955                 5.7900              10.030
# 2017-06-30               23.210                 5.9800               9.800
# 2017-07-31               23.910                 5.8100               9.750
# 2017-08-31               23.540                 5.5500               9.770
# 2017-09-30               25.340                 5.8800               9.900
# 2017-10-31               26.515                 5.8200               9.960
# 2017-11-30               24.925                 5.7300               9.947
# 2017-12-31               26.900                 5.5500               9.969
# 2018-01-31               27.290                 5.9380              10.360
# 2018-02-28               25.600                 5.7500              10.560
# 2018-03-31               24.470                 5.3340              10.420
# 2018-04-30               25.730                 5.2830              10.000
# 2018-05-31               22.220                 4.6865               9.850
# 2018-06-30               22.220                 4.5270               9.780
# 2018-07-31               23.700                 4.8500               9.750
# 2018-08-31               23.330                 4.3000               9.740
# 2018-09-30               23.450                 4.4685               7.450
# 2018-10-31               21.700                 3.9650               6.400
# 2018-11-30               22.520                 4.2370               6.300
# 2018-12-31               20.540                 3.9325               5.920
# 2019-01-31               21.720                 4.1100               6.080
# 2019-02-28               21.320                 4.2000              12.360
# 2019-03-31               20.100                 4.1540              12.260
# 2019-04-30               20.970                 4.5240              12.450
# 2019-05-31               18.940                 3.9730              12.450
# 2019-06-30               18.815                 4.0000              12.400
# 2019-07-31               17.960                 3.8750              12.550
# 2019-08-31               16.185                 3.4800              12.600
# 2019-09-30               16.175                 3.7115              12.750
# 2019-10-31               16.690                 3.6000              12.750
# 2019-11-30               15.490                 3.5270              12.800
# 2019-12-31               16.220                 3.7000                 NaN

# %% [markdown]
# ## Displaying the Correlation Matrix

# %%
df.pct_change().corr()
# Out:
#                        EURONEXT/ABN - Last  EURONEXT/SANTA - Last  \
# EURONEXT/ABN - Last               1.000000               0.810353
# EURONEXT/SANTA - Last             0.810353               1.000000
# EURONEXT/KA - Last                0.013801               0.078860
#
#                        EURONEXT/KA - Last
# EURONEXT/ABN - Last              0.013801
# EURONEXT/SANTA - Last            0.078860
# EURONEXT/KA - Last               1.000000

# %% [markdown]
# ## Plotting Correlations

# %%
# %matplotlib inline
import quandl

quandl.ApiConfig.api_key = QUANDL_API_KEY
df = quandl.get(['EURONEXT/ABN.4', 'EURONEXT/SANTA.4'], 
                start_date='2016-01-01', 
                end_date='2017-12-31')

df_filled = df.asfreq('D', method='ffill')
daily_changes= df_filled.pct_change()
abn_returns = daily_changes['EURONEXT/ABN - Last']
santa_returns = daily_changes['EURONEXT/SANTA - Last']
window = int(len(df_filled.index)/2)
df_corrs = abn_returns\
    .rolling(window=window, min_periods=window)\
    .corr(other=santa_returns)\
    .dropna()
df_corrs.plot(figsize=(12, 8));

# %% [markdown]
# ## Simple moving averages

# %%
# %matplotlib inline
import quandl
import pandas as pd

quandl.ApiConfig.api_key = QUANDL_API_KEY
df = quandl.get('EURONEXT/ABN.4')

df_filled = df.asfreq('D', method='ffill')
df_last = df['Last']

series_short = df_last.rolling(window=5, min_periods=5).mean()
series_long = df_last.rolling(window=30, min_periods=30).mean()

df_sma = pd.DataFrame(columns=['short', 'long'])
df_sma['short'] = series_short
df_sma['long'] = series_long
df_sma.plot(figsize=(12, 8));

# %% [markdown]
# ## Exponential Moving Average

# %%
# %matplotlib inline
import quandl
import pandas as pd

quandl.ApiConfig.api_key = QUANDL_API_KEY
df = quandl.get('EURONEXT/ABN.4')

df_filled = df.asfreq('D', method='ffill')
df_last = df['Last']

series_short = df_last.ewm(span=5).mean()
series_long = df_last.ewm(span=30).mean()

df_sma = pd.DataFrame(columns=['short', 'long'])
df_sma['short'] = series_short
df_sma['long'] = series_long
df_sma.plot(figsize=(12, 8));
